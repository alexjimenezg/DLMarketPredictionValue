# %% [markdown]
# # 08 Residual Deep Learning
#
# Sprint 8 — predict `log_next - log_curr` (residual vs no-change baseline) and reconstruct `pred_log_next = log_curr + pred_residual`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import json
import pandas as pd
from src.config import METRICS_DIR
from src.train_residual_dl import main

# %%
main()
metrics = json.loads((METRICS_DIR / 'residual_dl_metrics.json').read_text(encoding='utf-8'))
metrics['target_info']

# %%
for split in ('validation', 'test'):
    print(f'\n=== {split} ===')
    display(pd.DataFrame(metrics[split]).T)

# %%
pd.DataFrame(metrics['baseline_reference']).T
