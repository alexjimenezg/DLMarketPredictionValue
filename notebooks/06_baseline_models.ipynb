# %% [markdown]
# # 06 Baseline Models
#
# Sprint 6 — train and evaluate non-DL baselines (constant, previous-value, Ridge, HistGradientBoostingRegressor) on a temporal split.
#
# Target: `log_next_market_value`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import json
import pandas as pd
from src.config import METRICS_DIR
from src.train_baselines import train_and_evaluate_baselines

# %%
metrics = train_and_evaluate_baselines()
print('done')

# %%
for split in ('validation', 'test'):
    print(f'\n=== {split} ===')
    rows = metrics[split]
    df = pd.DataFrame(rows).T
    display(df)

# %%
metrics['split_info']
