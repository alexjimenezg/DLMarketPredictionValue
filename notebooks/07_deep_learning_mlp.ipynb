# %% [markdown]
# # 07 Deep Learning MLP
#
# Sprint 7 — Keras MLP (Huber loss, EarlyStopping, ReduceLROnPlateau) on the same temporal split as Sprint 6. Compared against `previous_value` and `histgb`.
#
# Target: `log_next_market_value`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import json
import pandas as pd
from src.config import METRICS_DIR
from src.train_dl import main

# %%
main()
metrics = json.loads((METRICS_DIR / 'deep_learning_metrics.json').read_text(encoding='utf-8'))
print('done')

# %%
for split in ('validation', 'test'):
    print(f'\n=== {split} ===')
    df = pd.DataFrame(metrics[split]).T
    display(df)

# %%
metrics['baseline_reference']
